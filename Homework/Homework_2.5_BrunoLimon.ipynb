# %%
# import the needed packages
import skmob

import pandas as pd
import geopandas as gpd

# %%
# Constructing a list of latitudes and longitudes concerning the points visited together with their timestamp
# the first element of the lists corresponds to the day

data_list = [[1, 43.705259, 10.427653, '2022-09-25 8:00:00'],
             [1, 43.706169, 10.415231, '2022-09-25 8:30:00'],
             [1, 43.708022, 10.41629,  '2022-09-25 9:00:00'],
             [1, 43.705259, 10.427653, '2022-09-25 9:30:00'],
             [1, 43.707393, 10.429519, '2022-09-25 14:00:00'],
             [1, 43.717609, 10.404205, '2022-09-25 20:00:00'],
             [1, 43.705259, 10.427653, '2022-09-26 8:00:00'],
             [2, 43.705259, 10.427653, '2022-09-27 7:45:00'],
             [2, 43.720824, 10.408009, '2022-09-27 8:30:00'],
             [2, 43.726728, 10.412141, '2022-09-27 16:00:00'],
             [2, 43.705259, 10.427653, '2022-09-27 17:45:00'],
             [3, 43.705259, 10.427653, '2022-09-28 7:45:00'],
             [3, 43.720824, 10.408009, '2022-09-28 8:30:00'],
             [3, 43.705259, 10.427653, '2022-09-28 17:45:00'],
             [4, 43.705259, 10.427653, '2022-09-28 8:45:00'],
             [4, 43.720824, 10.408009, '2022-09-28 9:30:00'],
             [4, 43.705259, 10.427653, '2022-09-28 14:45:00'],]

# %%
# Taking the previous list of addressess, we can build a trajectory dataframe with the help of scikit mobility
tdf = skmob.TrajDataFrame(data_list, user_id=0, latitude=1, longitude=2, datetime=3)
print(type(tdf))
tdf.head()
# Out:
# <class 'skmob.core.trajectorydataframe.TrajDataFrame'>
#    uid        lat        lng            datetime
# 0    1  43.705259  10.427653 2022-09-25 08:00:00
# 1    1  43.706169  10.415231 2022-09-25 08:30:00
# 2    1  43.708022  10.416290 2022-09-25 09:00:00
# 3    1  43.705259  10.427653 2022-09-25 09:30:00
# 4    1  43.707393  10.429519 2022-09-25 14:00:00

# %%
# Plotting the different trajectories for each day
tdf.plot_trajectory()
# Out:
# C:\Users\Pavilion\anaconda3\envs\Geospatial\lib\site-packages\skmob\core\trajectorydataframe.py:569: UserWarning: Only the trajectories of the first 10 users will be plotted. Use the argument `max_users` to specify the desired number of users, or filter the TrajDataFrame.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# C:\Users\Pavilion\anaconda3\envs\Geospatial\lib\site-packages\skmob\core\trajectorydataframe.py:569: UserWarning: If necessary, trajectories will be down-sampled to have at most `max_points` points. To avoid this, specify `max_points=None`.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# ...
